# %% [markdown]
# # AAVE Tweets Query

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 3.1 MB/s eta 0:00:00
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# ## 11-12

# %%
# Creating list to append tweet data to
tweets_list_1 = []
# max_tweets = 1000

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#aave since:2022-10-31 until:2023-1-1 lang:en min_faves:0 exclude:retweets').get_items()):
  tweets_list_1.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id
#  if i >= max_tweets:
#            break
# Out:
# <ipython-input-76-36c99d0132d2>:7: FutureWarning:
#
# content is deprecated, use rawContent instead

# %%
tweets_list_1 = pd.DataFrame(tweets_list_1, columns=['Date', 'Text', 'Hashtags'])

# %%
tweets_list_1.head()
# Out:
#                        Date  \
# 0 2022-12-31 23:53:08+00:00
# 1 2022-12-31 23:38:08+00:00
# 2 2022-12-31 23:23:08+00:00
# 3 2022-12-31 23:11:04+00:00
# 4 2022-12-31 23:08:08+00:00
#
#                                                 Text  \
# 0  😥 LIQUIDATION LOOMING 😥 \n \n$8,615 position a...
# 1  ⚠️ LIQUIDATION APPROACHING ⚠️ \n \n$3,892 posi...
# 2  ⚰️ LIQUIDATED ⚰️ \n \n$946 liquidated on #aave...
# 3  Get ready here we go #Dump #Crypto #LFG #oppor...
# 4  😥 LIQUIDATION LOOMING 😥 \n \n$8,916 position a...
#
#                                             Hashtags
# 0       [aave, credprotocol, defi, liquidation, eth]
# 1       [aave, credprotocol, defi, liquidation, eth]
# 2       [aave, credprotocol, defi, liquidation, eth]
# 3  [Dump, Crypto, LFG, opportunities, BTC, ETH, S...
# 4       [aave, credprotocol, defi, liquidation, eth]

# %%
tweets_list_1.to_csv("tweets_aave_11-12.csv")

# %% [markdown]
# ## 9-10

# %%
# Creating list to append tweet data to
tweets_list_2 = []
# max_tweets = 1000

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#aave since:2022-8-31 until:2022-10-31 lang:en min_faves:0 exclude:retweets').get_items()):
  tweets_list_2.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id
#  if i >= max_tweets:
#            break
# Out:
# <ipython-input-12-23e3a2c3e5d6>:7: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list_2.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id

# %%
tweets_list_2 = pd.DataFrame(tweets_list_2, columns=['Date', 'Text', 'Hashtags'])

# %%
tweets_list_2.head()
# Out:
#                        Date  \
# 0 2022-10-30 23:29:08+00:00
# 1 2022-10-30 23:05:08+00:00
# 2 2022-10-30 23:05:05+00:00
# 3 2022-10-30 22:04:56+00:00
# 4 2022-10-30 22:04:53+00:00
#
#                                                 Text      Hashtags
# 0  🚨 Market Move Alert on #AAVE🚨\n\nThis signal w...  [AAVE, AAVE]
# 1  In the past hour, $AAVE has gained 9 new holde...        [AAVE]
# 2  The current price of one $AAVE coin is: $83.34...        [AAVE]
# 3  In the past hour, $AAVE has gained 9 new holde...        [AAVE]
# 4  The current price of one $AAVE coin is: $84.26...        [AAVE]

# %%
tweets_list_2.to_csv("tweets_aave_9-10.csv")

# %% [markdown]
# ## 6-8

# %%
# Creating list to append tweet data to
tweets_list_3 = []
# max_tweets = 1000

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#aave since:2022-5-31 until:2022-8-31 lang:en min_faves:0 exclude:retweets').get_items()):
  tweets_list_3.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id
#  if i >= max_tweets:
#            break
# Out:
# <ipython-input-20-413fed9d7029>:7: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list_3.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id

# %%
tweets_list_3 = pd.DataFrame(tweets_list_3, columns=['Date', 'Text', 'Hashtags'])

# %%
tweets_list_3.head()
# Out:
#                        Date  \
# 0 2022-08-30 23:53:08+00:00
# 1 2022-08-30 23:47:20+00:00
# 2 2022-08-30 23:46:09+00:00
# 3 2022-08-30 23:38:08+00:00
# 4 2022-08-30 23:23:09+00:00
#
#                                                 Text  \
# 0  ⚠️ LIQUIDATION APPROACHING ⚠️ \n \n$10,144 pos...
# 1  $Brise the Future! #BRC20\n#dogecoin $BTC #LTC...
# 2  #Believed $Brise!\n\n#dogecoin $BTC #LTC #XRP ...
# 3  ⚠️ LIQUIDATION APPROACHING ⚠️ \n \n$6,899 posi...
# 4  😥 LIQUIDATION LOOMING 😥 \n \n$5,546 position a...
#
#                                             Hashtags
# 0       [aave, credprotocol, defi, liquidation, eth]
# 1  [BRC20, dogecoin, LTC, XRP, Tezos, SKL, DASH, ...
# 2  [Believed, dogecoin, LTC, XRP, Tezos, SKL, DAS...
# 3       [aave, credprotocol, defi, liquidation, eth]
# 4       [aave, credprotocol, defi, liquidation, eth]

# %%
tweets_list_3.to_csv("tweets_aave_6-8.csv")

# %% [markdown]
# ## 3-5

# %%
# Creating list to append tweet data to
tweets_list_4 = []
# max_tweets = 1000

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#aave since:2022-2-28 until:2022-5-31 lang:en min_faves:0 exclude:retweets').get_items()):
  tweets_list_4.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id
#  if i >= max_tweets:
#            break
# Out:
# <ipython-input-31-4c6062a852bd>:7: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list_4.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id

# %%
tweets_list_4 = pd.DataFrame(tweets_list_4, columns=['Date', 'Text', 'Hashtags'])

# %%
tweets_list_4.head()
# Out:
#                        Date  \
# 0 2022-05-30 23:55:00+00:00
# 1 2022-05-30 23:50:05+00:00
# 2 2022-05-30 23:50:00+00:00
# 3 2022-05-30 23:50:00+00:00
# 4 2022-05-30 23:50:00+00:00
#
#                                                 Text  \
# 0  ↑ Aave V2 Deposit APY for USDC on Polygon is 1...
# 1  Top #cryptos performers of the day: \n#WAVES  ...
# 2  ↑ Aave V2 Borrow APY for USDT on Polygon is 2....
# 3  ↓ Aave V2 Deposit APY for USDC on Polygon is 1...
# 4  ↓ Aave V2 Borrow APY for USDC on Polygon is 2....
#
#                                             Hashtags
# 0               [defiratealert, Aave, USDC, Polygon]
# 1  [cryptos, WAVES, TRB, HNT, AXS, SNX, ENS, C98,...
# 2               [defiratealert, Aave, USDT, Polygon]
# 3               [defiratealert, Aave, USDC, Polygon]
# 4               [defiratealert, Aave, USDC, Polygon]

# %%
tweets_list_4.to_csv("tweets_aave_3-5.csv")

# %% [markdown]
# ## 1-2

# %%
# Creating list to append tweet data to
tweets_list_5 = []
# max_tweets = 1000

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#aave since:2022-1-1 until:2022-2-28 lang:en min_faves:0 exclude:retweets').get_items()):
  tweets_list_5.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id
#  if i >= max_tweets:
#            break
# Out:
# <ipython-input-35-ef2a1a940a9b>:7: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list_5.append([tweet.date, tweet.content,  tweet.hashtags]) #tweet.id

# %%
tweets_list_5 = pd.DataFrame(tweets_list_5, columns=['Date', 'Text', 'Hashtags'])

# %%
tweets_list_5.head()
# Out:
#                        Date  \
# 0 2022-02-27 23:35:21+00:00
# 1 2022-02-27 23:34:39+00:00
# 2 2022-02-27 23:09:29+00:00
# 3 2022-02-27 23:08:28+00:00
# 4 2022-02-27 23:08:01+00:00
#
#                                                 Text  \
# 0  @iamtomnash try #AAVE, better  rate than #bank...
# 1  3/ To put it in perspective that is the curren...
# 2  $AAVE\n🔻 Decreased 3.56% in 3.2 hour(s)\n💵 Pri...
# 3  @CarlBMenger we have better rate than #bankers...
# 4  @AvidCommentator #SWIFT ... is irrelevant  &gt...
#
#                        Hashtags
# 0               [AAVE, bankers]
# 1         [AAVE, Kava, Osmosis]
# 2   [AAVE, AAVEUSDT, CryptoBOT]
# 3               [bankers, AAVE]
# 4  [SWIFT, DEFI, AAVE, bankers]

# %%
tweets_list_5.to_csv("tweets_aave_1-2.csv")

# %% [markdown]
# ## Merge

# %%
df1= tweets_list_1
df2= tweets_list_2
df3= tweets_list_3
df4= tweets_list_4
df5= tweets_list_5

# %%
df_all = pd.concat([df1, df2, df3, df4, df5])

# %%
df_all.tail()
# Out:
#                           Date  \
# 5568 2022-01-01 01:00:09+00:00
# 5569 2022-01-01 00:57:14+00:00
# 5570 2022-01-01 00:55:35+00:00
# 5571 2022-01-01 00:48:07+00:00
# 5572 2022-01-01 00:45:09+00:00
#
#                                                    Text  \
# 5568  A Jackrabbit TV subscriber just sold #AAVE-PER...
# 5569  #AAVE is forming a triangle pattern (4H chart)...
# 5570  #AAVE - long alert 💵💰\n\nExchange     : FTX\nM...
# 5571  $AAVE\nContinues to be super strong. If we get...
# 5572  #aave price analysis. The daily standard devia...
#
#                                                Hashtags
# 5568             [AAVE, FTX, Jrling, Potato, MACD, DCA]
# 5569  [AAVE, Bybit, USDT, Cryptotrading, Crypto, tra...
# 5570                                   [AAVE, BTC, ETH]
# 5571                                             [AAVE]
# 5572                                             [aave]

# %%
df_all['Date'] = pd.to_datetime(df_all['Date'], utc=True)

df_all['Date'] = df_all['Date'].apply(lambda x: x.replace(tzinfo=None))

df_all['Date'] = pd.to_datetime(df_all['Date'])

# set time column as index
df_all = df_all.set_index('Date')

# sort dataframe by index (i.e., by time) in ascending order
df_all = df_all.sort_index()

# %%
df_all = df_all.reset_index()

# %%
df_all.tail()
# Out:
#                      Date                                               Text  \
# 55701 2022-12-31 23:08:08  😥 LIQUIDATION LOOMING 😥 \n \n$8,916 position a...
# 55702 2022-12-31 23:11:04  Get ready here we go #Dump #Crypto #LFG #oppor...
# 55703 2022-12-31 23:23:08  ⚰️ LIQUIDATED ⚰️ \n \n$946 liquidated on #aave...
# 55704 2022-12-31 23:38:08  ⚠️ LIQUIDATION APPROACHING ⚠️ \n \n$3,892 posi...
# 55705 2022-12-31 23:53:08  😥 LIQUIDATION LOOMING 😥 \n \n$8,615 position a...
#
#                                                 Hashtags
# 55701       [aave, credprotocol, defi, liquidation, eth]
# 55702  [Dump, Crypto, LFG, opportunities, BTC, ETH, S...
# 55703       [aave, credprotocol, defi, liquidation, eth]
# 55704       [aave, credprotocol, defi, liquidation, eth]
# 55705       [aave, credprotocol, defi, liquidation, eth]

# %%
df_all.to_csv("tweets_aave_2022.csv")

# %% [markdown]
# # Tweet Volume

# %%
df_all['Date'] = pd.to_datetime(df_all['Date'])  # Convert to datetime index
daily_tweet_count = df_all.set_index('Date')['Text'].resample('D').count()
print(daily_tweet_count)
# Out:
# Date
# 2022-01-01     64
# 2022-01-02     70
# 2022-01-03    299
# 2022-01-04    247
# 2022-01-05    231
#              ...
# 2022-12-27    178
# 2022-12-28    163
# 2022-12-29    193
# 2022-12-30    199
# 2022-12-31    172
# Freq: D, Name: Text, Length: 365, dtype: int64

# %%
daily_tweet_count = daily_tweet_count.to_frame(name='Tweet Volume').reset_index()

# %%
daily_tweet_count
# Out:
#           Date  Tweet Volume
# 0   2022-01-01            64
# 1   2022-01-02            70
# 2   2022-01-03           299
# 3   2022-01-04           247
# 4   2022-01-05           231
# ..         ...           ...
# 360 2022-12-27           178
# 361 2022-12-28           163
# 362 2022-12-29           193
# 363 2022-12-30           199
# 364 2022-12-31           172
#
# [365 rows x 2 columns]

# %%
daily_tweet_count.to_csv('tweet_volume_aave_2022.csv', index=False)

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=daily_tweet_count['Date'], y=daily_tweet_count['Tweet Volume'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='2022 AAVE Daily Tweet Volume', xaxis_title='Date', yaxis_title='Tweet Volume')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Text Processing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re

# Download stopwords and stemmer
nltk.download('stopwords')
nltk.download('punkt')

# Define the preprocessing function
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    # Check if text is NaN
    if pd.isna(text):
        return ""
    
    # Convert to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove non-alphabetic characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenize the text
    words = word_tokenize(text)

    # Remove stop words and punctuation
    words = [word for word in words if word not in stop_words and word.isalpha()]

    # Join the remaining words into a string
    text = ' '.join(words)

    return text

# Apply the preprocessing function to the 'Text' column
df_all['Preprocessed Text'] = df_all['Text'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df_all.tail()
# Out:
#                                                                   Text  \
# Date
# 2022-12-31 23:08:08  😥 LIQUIDATION LOOMING 😥 \n \n$8,916 position a...
# 2022-12-31 23:11:04  Get ready here we go #Dump #Crypto #LFG #oppor...
# 2022-12-31 23:23:08  ⚰️ LIQUIDATED ⚰️ \n \n$946 liquidated on #aave...
# 2022-12-31 23:38:08  ⚠️ LIQUIDATION APPROACHING ⚠️ \n \n$3,892 posi...
# 2022-12-31 23:53:08  😥 LIQUIDATION LOOMING 😥 \n \n$8,615 position a...
#
#                                                               Hashtags  \
# Date
# 2022-12-31 23:08:08       [aave, credprotocol, defi, liquidation, eth]
# 2022-12-31 23:11:04  [Dump, Crypto, LFG, opportunities, BTC, ETH, S...
# 2022-12-31 23:23:08       [aave, credprotocol, defi, liquidation, eth]
# 2022-12-31 23:38:08       [aave, credprotocol, defi, liquidation, eth]
# 2022-12-31 23:53:08       [aave, credprotocol, defi, liquidation, eth]
#
#                                                      Preprocessed Text
# Date
# ...

# %%
df_all = df_all.reset_index()

# %%
# Save the cleaned DataFrame to a new CSV file
df_all.to_csv('cleaned_tweets_aave_2022.csv', index=False)

# %% [markdown]
# # Sentiment Analysis

# %%
! pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df_all.dropna(subset=['Date'], inplace=True)

# %%
df_all.tail()
# Out:
#                      Date                                               Text  \
# 55701 2022-12-31 23:08:08  😥 LIQUIDATION LOOMING 😥 \n \n$8,916 position a...
# 55702 2022-12-31 23:11:04  Get ready here we go #Dump #Crypto #LFG #oppor...
# 55703 2022-12-31 23:23:08  ⚰️ LIQUIDATED ⚰️ \n \n$946 liquidated on #aave...
# 55704 2022-12-31 23:38:08  ⚠️ LIQUIDATION APPROACHING ⚠️ \n \n$3,892 posi...
# 55705 2022-12-31 23:53:08  😥 LIQUIDATION LOOMING 😥 \n \n$8,615 position a...
#
#                                                 Hashtags  \
# 55701       [aave, credprotocol, defi, liquidation, eth]
# 55702  [Dump, Crypto, LFG, opportunities, BTC, ETH, S...
# 55703       [aave, credprotocol, defi, liquidation, eth]
# 55704       [aave, credprotocol, defi, liquidation, eth]
# 55705       [aave, credprotocol, defi, liquidation, eth]
#
#                                        Preprocessed Text
# 55701  liquidation looming position risk aave wallet ...
# ...

# %%
DF = df_all
DF.head()
# Out:
#                  Date                                               Text  \
# 0 2022-01-01 00:45:09  #aave price analysis. The daily standard devia...
# 1 2022-01-01 00:48:07  $AAVE\nContinues to be super strong. If we get...
# 2 2022-01-01 00:55:35  #AAVE - long alert 💵💰\n\nExchange     : FTX\nM...
# 3 2022-01-01 00:57:14  #AAVE is forming a triangle pattern (4H chart)...
# 4 2022-01-01 01:00:09  A Jackrabbit TV subscriber just sold #AAVE-PER...
#
#                                             Hashtags  \
# 0                                             [aave]
# 1                                             [AAVE]
# 2                                   [AAVE, BTC, ETH]
# 3  [AAVE, Bybit, USDT, Cryptotrading, Crypto, tra...
# 4             [AAVE, FTX, Jrling, Potato, MACD, DCA]
#
#                                    Preprocessed Text
# 0  aave price analysis daily standard deviation p...
# 1  aave continues super strong get c wave move lo...
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Convert the 'Date' column to a datetime object and set it as the index
DF['Date'] = pd.to_datetime(DF['Date'], errors='coerce')
DF.set_index('Date', inplace=True)

# Define a function to compute the sentiment score for each day
def daily_sentiment_score(text):
    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']

# Compute the daily sentiment score using resample and apply
df_daily = DF['Preprocessed Text'].resample('D').apply(lambda x: x.apply(daily_sentiment_score).mean())

# %%
df_daily
# Out:
# Date
# 2022-01-01    0.232317
# 2022-01-02    0.212010
# 2022-01-03    0.109949
# 2022-01-04    0.065988
# 2022-01-05    0.044562
#                 ...
# 2022-12-27   -0.011484
# 2022-12-28   -0.039476
# 2022-12-29    0.020103
# 2022-12-30   -0.027850
# 2022-12-31   -0.041984
# Freq: D, Name: Preprocessed Text, Length: 365, dtype: float64

# %%
df_daily_sentiment = df_daily.to_frame(name='Sentiment Score').reset_index()

# %%
df_daily_sentiment.columns
# Out:
# Index(['Date', 'Sentiment Score'], dtype='object')

# %%
df_daily_sentiment.head()
# Out:
#         Date  Sentiment Score
# 0 2022-01-01         0.232317
# 1 2022-01-02         0.212010
# 2 2022-01-03         0.109949
# 3 2022-01-04         0.065988
# 4 2022-01-05         0.044562

# %%
df_daily_sentiment['Sentiment Score'].fillna(0.000000, inplace=True)

# %%
df_daily_sentiment
# Out:
#           Date  Sentiment Score
# 0   2022-01-01         0.232317
# 1   2022-01-02         0.212010
# 2   2022-01-03         0.109949
# 3   2022-01-04         0.065988
# 4   2022-01-05         0.044562
# ..         ...              ...
# 360 2022-12-27        -0.011484
# 361 2022-12-28        -0.039476
# 362 2022-12-29         0.020103
# 363 2022-12-30        -0.027850
# 364 2022-12-31        -0.041984
#
# [365 rows x 2 columns]

# %%
df_daily_sentiment.to_csv('sentiment_aave_2022.csv', index=False)

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=df_daily_sentiment['Date'], y=df_daily_sentiment['Sentiment Score'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='2022 AAVE Daily Twitter Sentiment Score', xaxis_title='Date', yaxis_title='Sentiment Score')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
positive_count = len(df_daily_sentiment[df_daily_sentiment['Sentiment Score'] > 0])
negative_count = len(df_daily_sentiment[df_daily_sentiment['Sentiment Score'] < 0])

# %%
import plotly.express as px

# Calculate positive and negative sentiment counts
positive_count = (df_daily_sentiment['Sentiment Score'] > 0).sum()
negative_count = (df_daily_sentiment['Sentiment Score'] < 0).sum()

# Create a dataframe for histogram
hist_df = pd.DataFrame({
    'Sentiment': ['Positive', 'Negative'],
    'Count': [positive_count, negative_count]
})

# Create a plotly histogram
fig = px.histogram(hist_df, x='Sentiment', y='Count', color='Sentiment', 
                   title='2022 AAVE Twitter Sentiment Distribution')

# Set y-axis label
fig.update_layout(yaxis_title='Count (days)')

# Add count number on each bar
fig.update_traces(texttemplate='%{y}', textposition='outside')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # AAVE Price Query

# %%
from urllib import request

# %%
# Define the remote file to retrieve
remote_url = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=AAVE&market=USD&apikey=90UFYXKT4A6OCPSL&datatype=csv'

# Define the local filename to save data
local_file = 'price_aave.csv'

# Download remote and save locally
request.urlretrieve(remote_url, local_file)
# Out:
# ('price_aave.csv', <http.client.HTTPMessage at 0x7f757103be20>)

# %%
price = pd.read_csv('price_aave.csv')

# %%
price.tail()
# Out:
#       timestamp  open (USD)  high (USD)  low (USD)  close (USD)  open (USD).1  \
# 861  2020-10-19      40.820      41.000     35.912       35.980        40.820
# 862  2020-10-18      41.359      41.425     39.428       40.750        41.359
# 863  2020-10-17      39.371      43.235     38.206       41.365        39.371
# 864  2020-10-16      43.017      43.800     39.092       39.461        43.017
# 865  2020-10-15      51.430      59.000     42.747       42.999        51.430
#
#      high (USD).1  low (USD).1  close (USD).1     volume  market cap (USD)
# 861        41.000       35.912         35.980  86475.936         86475.936
# 862        41.425       39.428         40.750  30917.953         30917.953
# 863        43.235       38.206         41.365  41971.143         41971.143
# 864        43.800       39.092         39.461  90836.412         90836.412
# 865        59.000       42.747         42.999  98648.870         98648.870

# %%
price['timestamp'] = pd.to_datetime(price['timestamp'])

# %%
price_new = price[58:423]

# %%
price_new.tail()
# Out:
#      timestamp  open (USD)  high (USD)  low (USD)  close (USD)  open (USD).1  \
# 418 2022-01-05       252.0       259.4      214.9        230.3         252.0
# 419 2022-01-04       267.2       269.5      249.8        252.1         267.2
# 420 2022-01-03       265.3       286.4      262.7        267.2         265.3
# 421 2022-01-02       266.3       269.1      253.1        265.3         266.3
# 422 2022-01-01       253.9       266.8      250.2        266.4         253.9
#
#      high (USD).1  low (USD).1  close (USD).1      volume  market cap (USD)
# 418         259.4        214.9          230.3  189611.084        189611.084
# 419         269.5        249.8          252.1  173580.453        173580.453
# 420         286.4        262.7          267.2  252013.495        252013.495
# 421         269.1        253.1          265.3  122031.041        122031.041
# 422         266.8        250.2          266.4  110355.452        110355.452

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=price_new['timestamp'], y=price_new['close (USD)'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='2022 AAVE Daily Price', xaxis_title='Date', yaxis_title='Close Price')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
